# %% [markdown]
# ## import lib

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## import Data

# %%
df = pd.read_csv('dataset/immbilierAlgerie.csv')

# %%
df.head()
# Out:
#    identifiant    ville     CP  revenu  remboursement  duree        type  \
# 0            0  OUARGLA  30100  3669.0        1130.05    240  immobilier
# 1            1    ALGER  16009  5310.0         240.00     64  automobile
# 2            1    ALGER  16009  5310.0        1247.85    300  immobilier
# 3            2     ORAN  25010  1873.0         552.54    240  immobilier
# 4            3     ORAN  25010  1684.0         586.03    180  immobilier
#
#     taux
# 0  1.168
# 1  3.701
# 2  1.173
# 3  0.972
# 4  1.014

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   identifiant    244 non-null    int64
#  1   ville          244 non-null    object
#  2   CP             244 non-null    int64
#  3   revenu         244 non-null    float64
#  4   remboursement  244 non-null    float64
#  5   duree          244 non-null    int64
#  6   type           244 non-null    object
#  7   taux           244 non-null    float64
# dtypes: float64(3), int64(3), object(2)
# memory usage: 15.4+ KB

# %%
df['taux_endettement'] = df['remboursement'] * 100 / df['revenu']
df['cout_total'] = df['remboursement'] *df["duree"]
df['benefices'] = df['cout_total']  * ((df['taux']/100) / 24 )

# %%
df.head()
# Out:
#    identifiant    ville     CP  revenu  remboursement  duree        type  \
# 0            0  OUARGLA  30100  3669.0        1130.05    240  immobilier
# 1            1    ALGER  16009  5310.0         240.00     64  automobile
# 2            1    ALGER  16009  5310.0        1247.85    300  immobilier
# 3            2     ORAN  25010  1873.0         552.54    240  immobilier
# 4            3     ORAN  25010  1684.0         586.03    180  immobilier
#
#     taux  taux_endettement  cout_total   benefices
# 0  1.168         30.799945    271212.0  131.989840
# 1  3.701          4.519774     15360.0   23.686400
# 2  1.173         23.500000    374355.0  182.966006
# 3  0.972         29.500267    132609.6   53.706888
# 4  1.014         34.799881    105485.4   44.567581

# %% [markdown]
# ### Nombre de personnes ayant dépassé ce seuil

# %%
df_35 = df[df["taux_endettement"] > 35]

# %%
df_35.head()
# Out:
#     identifiant        ville     CP  revenu  remboursement  duree        type  \
# 7             6  CONSTANTINE  31008  1867.0         711.33    240  immobilier
# 8             7        SETIF  13000  5486.0        2956.95    300  immobilier
# 10            9         ORAN  25012  1386.0         612.61    180  immobilier
# 15           14      OUARGLA  31400  2413.0        1334.39    300  immobilier
# 21           20  CONSTANTINE  25001  3318.0        1237.61    240  immobilier
#
#      taux  taux_endettement  cout_total   benefices
# 7   1.196         38.100161    170719.2   85.075068
# 8   1.184         53.899927    887085.0  437.628600
# 10  1.284         44.199856    110269.8   58.994343
# 15  1.154         55.300041    400317.0  192.485758
# 21  1.148         37.299879    297026.4  142.077628

# %%
df_35.shape
# Out:
# (59, 11)

# %%
print("Nombre de personnes ayant dépassé ce seuil" , df_35.shape[0] )
# Out:
# Nombre de personnes ayant dépassé ce seuil 59

# %% [markdown]
# ### Même question, mais cette fois-ci uniquement sur l’agence Algeroise

# %%
df_35_ar = df_35[df_35["ville"] == "ALGER"]

# %%
df_35_ar
# Out:
#      identifiant  ville     CP  revenu  remboursement  duree        type  \
# 70            67  ALGER  16014  5598.0        2395.94    240  immobilier
# 75            72  ALGER  16012  5981.0        2230.91    240  immobilier
# 89            85  ALGER  16005  6341.0        2980.27    240  immobilier
# 129          122  ALGER  16001  6536.0        2457.54    120  immobilier
# 143          134  ALGER  16003  2870.0        1021.72    180  immobilier
# 155          145  ALGER  16017  5978.0        2193.93    300  immobilier
# 181          168  ALGER  16003  6366.0        2807.41    240  immobilier
# 183          170  ALGER  16019  2384.0        1311.20    240  immobilier
# 186          173  ALGER  16006  6784.0        3744.77    180  immobilier
# 195          182  ALGER  16019  4068.0        1505.16    240  immobilier
# 196          183  ALGER  16001  2330.0         871.42    240  immobilier
# 203          190  ALGER  16005  2576.0         984.03    240  immobilier
# ...

# %%
print("Nombre de personnes ayant dépassé ce seuil d'un ALGER" , df_35_ar.shape[0] )
# Out:
# Nombre de personnes ayant dépassé ce seuil d'un ALGER 16

# %% [markdown]
# ### ajouter une variable nommée risque, qui nous permettrait d’identifier facilement les clients à risque

# %%
df.head()
# Out:
#    identifiant    ville     CP  revenu  remboursement  duree        type  \
# 0            0  OUARGLA  30100  3669.0        1130.05    240  immobilier
# 1            1    ALGER  16009  5310.0         240.00     64  automobile
# 2            1    ALGER  16009  5310.0        1247.85    300  immobilier
# 3            2     ORAN  25010  1873.0         552.54    240  immobilier
# 4            3     ORAN  25010  1684.0         586.03    180  immobilier
#
#     taux  taux_endettement  cout_total   benefices
# 0  1.168         30.799945    271212.0  131.989840
# 1  3.701          4.519774     15360.0   23.686400
# 2  1.173         23.500000    374355.0  182.966006
# 3  0.972         29.500267    132609.6   53.706888
# 4  1.014         34.799881    105485.4   44.567581

# %%
df['risque'] = df["taux_endettement"] > 35

# %%
df.head(13)
# Out:
#     identifiant        ville     CP  revenu  remboursement  duree        type  \
# 0             0      OUARGLA  30100  3669.0        1130.05    240  immobilier
# 1             1        ALGER  16009  5310.0         240.00     64  automobile
# 2             1        ALGER  16009  5310.0        1247.85    300  immobilier
# 3             2         ORAN  25010  1873.0         552.54    240  immobilier
# 4             3         ORAN  25010  1684.0         586.03    180  immobilier
# 5             4         ORAN  25012  1476.0         423.61    240  immobilier
# 6             5        ALGER  16016  2476.0         836.89    240  immobilier
# 7             6  CONSTANTINE  31008  1867.0         711.33    240  immobilier
# 8             7        SETIF  13000  5486.0        2956.95    300  immobilier
# 9             8     TELEMCEN  33200  3578.0         751.38    180  immobilier
# 10            9         ORAN  25012  1386.0         612.61    180  immobilier
# ...

# %% [markdown]
# ### Combien de prêts automobiles ont été accordés ? Quel est le coût total moyen de ceuxci ?

# %%
df_car = df[df['type'] == "automobile"]

# %%
df_car
# Out:
#      identifiant        ville     CP  revenu  remboursement  duree  \
# 1              1        ALGER  16009  5310.0          240.0     64
# 65            63        SETIF  30000  4114.0          302.9     24
# 67            64  CONSTANTINE  25004  4326.0          236.1     46
# 87            83      OUARGLA  31000  2207.0          253.3     60
# 100           95        ALGER  16016  6069.0          341.4     24
# 106          101  CONSTANTINE  31008  4737.0          214.8     47
# 120          113         ORAN  30006  2314.0          253.2     49
# 132          124        SETIF  13000  3493.0          309.9     56
# 141          133        ALGER  16011  3099.0          291.2     78
# 154          144         ORAN  25010  2240.0          316.6     81
# 158          147         ORAN  16015  1288.0          269.8     30
# 159          148      OUARGLA  31000  1872.0          250.5     80
# 172          159        ALGER  16010  3238.0          315.8     55
# ...

# %%
print("Combien de prêts automobiles ont été accordés " , df_car.shape[0] )
# Out:
# Combien de prêts automobiles ont été accordés  16

# %%
print(" Total moyen " , df_car["cout_total"].mean())
# Out:
#  Total moyen  13665.0

# %% [markdown]
# ### Quel est le bénéfice mensuel total réalisé par l’agence de ouargla ?

# %%
df_ouargla = df[df["ville"] == "OUARGLA"]

# %%
df_ouargla
# Out:
#      identifiant    ville     CP  revenu  remboursement  duree        type  \
# 0              0  OUARGLA  30100  3669.0        1130.05    240  immobilier
# 15            14  OUARGLA  31400  2413.0        1334.39    300  immobilier
# 31            30  OUARGLA  31000  1785.0         514.08    240  immobilier
# 41            40  OUARGLA  31400  3837.0         621.59    240  immobilier
# 50            49  OUARGLA  30100  2931.0        1442.05    240  immobilier
# 56            55  OUARGLA  31400  3884.0         881.67    180  immobilier
# 57            56  OUARGLA  31500  2185.0         642.39    240  immobilier
# 68            65  OUARGLA  30100  3870.0        1091.34    180  immobilier
# 72            69  OUARGLA  31000  2278.0         872.47    240  immobilier
# 73            70  OUARGLA  30100  2794.0         508.51    180  immobilier
# 82            79  OUARGLA  31300  2522.0         448.92    240  immobilier
# ...

# %%
df_ouargla['cout_total_month'] = df_ouargla['remboursement'] * 4
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_2664\3210046544.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ouargla['cout_total_month'] = df_ouargla['remboursement'] * 4

# %%
df_ouargla
# Out:
#      identifiant    ville     CP  revenu  remboursement  duree        type  \
# 0              0  OUARGLA  30100  3669.0        1130.05    240  immobilier
# 15            14  OUARGLA  31400  2413.0        1334.39    300  immobilier
# 31            30  OUARGLA  31000  1785.0         514.08    240  immobilier
# 41            40  OUARGLA  31400  3837.0         621.59    240  immobilier
# 50            49  OUARGLA  30100  2931.0        1442.05    240  immobilier
# 56            55  OUARGLA  31400  3884.0         881.67    180  immobilier
# 57            56  OUARGLA  31500  2185.0         642.39    240  immobilier
# 68            65  OUARGLA  30100  3870.0        1091.34    180  immobilier
# 72            69  OUARGLA  31000  2278.0         872.47    240  immobilier
# 73            70  OUARGLA  30100  2794.0         508.51    180  immobilier
# 82            79  OUARGLA  31300  2522.0         448.92    240  immobilier
# ...
