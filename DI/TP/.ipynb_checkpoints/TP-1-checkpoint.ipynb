\xa4q\xce\x11[\x94\x99\xbfp\x99~\x8eO*\xfe\xe9d\n@\xc7eu\x8fL\x86\'\xc9\x88\x82YP\xcbN\xf9`ot\xfa\x0f\x97\x0e\xb8\xdaq\x06\xc9U\x0c\xd8\xee\x82\xce\xac\x8cR)7\x19\x10[\xbed:\xa93\xce1\xb7d\xcc\x08d\xf9\xe0\x94\x9b\xf6\xb7\xa7 \xb4)\xd8\xa3\xdc\x9b\xd2\xa5o\xa7\xf6WxHa\xf4Au\x16g\xbaD\xb7k\x1f\xcb\x9e:k\x99\xfe>\x02\xc8\xc8\xdf+\xe8F\x08E\xdeL\xf6t8\x8c\xd5\xa0j\x10\xe1\xbfl\x96\nd\xb6\x0bM{\xc1l\x9f\xf6:>P\x8e\xe6\xe6\xe8\x17nW\xccw\x01\x1b\xc9\xd7\x89z\x9c\xf3\x0b3\x05\xeb\xa6\x92\xbdE\'\xc3\x90l\x96\x08\xf6\x96sb\xfe\xc2\x890\xc3$O \x15\xea\r\x17\xc6\x0f+\x9c@\xc5~j@\x8a\x88\x07z/\xe25\xbe\xc5\xb3\xa2v\xf6=\x04\xc6\x07\xbb\xee\xc9|\x04\x85\xbc\x89\xf0\xeb\xc7\x8b\x83\x01h\xb4\x8eXX\xac2\x12\x92\x03+\x92\xa1\xf095\xe1\xe1m\xa0\x1d3\xae*\xd2\x01\xbb\x99\xdd\xb0\x98\xa2O1/\xf39\xec\x8f\xd2\xc4\xbeG\xba\x84T\x83\xd0\xedE#\x82 ...

# %% [markdown]
# ## Convert To Matrix

# %%
def jpg_to_matrix(filename):
    with open(filename, 'rb') as f:
        data = f.read()

    matrix = []
    width = 0
    height = 0
    idx = 0

    # Extract width and height
    while idx < len(data):
        if data[idx] == 0xFF:
            marker = data[idx + 1]
            if marker == 0xC0 or marker == 0xC2:  # SOF marker (Start of Frame)
                height = (data[idx + 5] << 8) + data[idx + 6]
                width = (data[idx + 7] << 8) + data[idx + 8]
                idx += 9  # Move to the start of the image data
                break
            idx += 2
        else:
            idx += 1

    if width == 0 or height == 0:
        raise ValueError("Unable to determine image dimensions.")

    idx += 1  # Skip the marker

    # Read pixel data
    for h in range(height):
        row = []
        for w in range(width):
            if idx + 2 < len(data):  # Check if there's enough data
                pixel = (data[idx], data[idx + 1], data[idx + 2])  # RGB
                row.append(pixel)
                idx += 3
            else:
                break
        # Pad the row if it is shorter than the expected width
        while len(row) < width:
            row.append((0, 0, 0))  # Add black pixels (or any default value)
        matrix.append(row)

    return matrix, width, height

# %% [markdown]
# ## Determine the pixel resolution of IMG

# %%
IMG, img_width, img_height = jpg_to_matrix("images/54333326-3153-4716-b05c-91856c498125.jpg")

# %%
print(IMG[0])
# Out:
(25, 135, 22), (103, 244, 29), (182, 135, 240), (207, 238, 124), (109, 82, 47), (208, 173, 221), (49, 65, 72), (134, 100, 74), (148, 88, 80), (136, 189, 134), (87, 197, 248), (43, 142, 115), (87, 122, 87), (210, 191, 245), (63, 94, 236), (170, 86, 2), (27, 180, 204), (192, 210, 170), (98, 157, 63), (129, 128, 168), (226, 136, 8), (81, 124, 182), (212, 102, 220), (231, 198, 33), (179, 89, 106), (75, 17, 125), (153, 125, 249), (213, 208, 208), (149, 230, 15), (189, 216, 122), (43, 106, 149), (213, 240, 181), (118, 150, 148), (132, 64, 168), (223, 70, 198), (212, 163, 9), (37, 133, 187), (119, 46, 131), (126, 122, 157), (221, 39, 185), (191, 46, 189), (34, 198, 247), (34, 1, 178), (139, 132, 50), (161, 38, 40), (131, 40, 98), (90, 87, 102), (251, 48, 37), (223, 194, 209), (49, 214, 209), (89, 151, 250), (86, 178, 1), (94, 151, 184), (85, 135, 241), (110, 101, 53), (81, 95, 53), (204, 190, 57), (30, 78, 88), (35, 154, 219), (35, 162, 18), (72, 205, 115), (71, 50, 240), (190, 100, 65), (212, 203, 100), (63, 95, 159), (180, 217, 120), (11, 162, 17 ...

# %%
print(f'Final Image Width: {img_width}, Height: {img_height}')
# Out:
# Final Image Width: 20045, Height: 2358

# %% [markdown]
# ## Show the RGB values of the pixel IMG(10, 15)

# %%
print(f'RGB values of the pixel IMG(10, 15) is  {IMG[10][15]}')
# Out:
# RGB values of the pixel IMG(10, 15) is  (0, 0, 0)

# %% [markdown]
# ## Calculate the brightness of IMG

# %%
def calculate_brightness(IMG ,img_height , img_width  ):
    R_values = []
    G_values = []
    B_values = []
    brightness_values = [] 
    for i in range(0 , img_height) : 
        for j in range(0 , img_width) : 
            R_values.append(IMG[i][j][0])
            G_values.append(IMG[i][j][1])
            B_values.append(IMG[i][j][2])
            brightness = (0.29 * IMG[i][j][0] + 0.58 * IMG[i][j][1] + 0.11 * IMG[i][j][2])
            brightness_values.append(brightness)
            
    average_brightness = sum(brightness_values) / len(brightness_values)
    
    return  average_brightness , brightness_values

# %%
        
average_brightness ,brightness_values = calculate_brightness(IMG,img_height,img_width)

print(f'Average Brightness: {average_brightness}')
print(f' Brightness values : {brightness_values[:8]}')
# Out:
# Average Brightness: 0.44920894865263317
#  Brightness values : [106.02999999999999, 98.15, 171.75999999999996, 107.20999999999998, 108.11999999999999, 89.39, 132.03, 148.70999999999998]

# %% [markdown]
# ## Calculate the contrast of IMG

# %%
import math 

def calculate_contrast(average_brightness , brightness_values , N , M) : 
    
    contrast_sum = 0
    for brightness in brightness_values:
        
        contrast_sum += (brightness - average_brightness) ** 2
        
    contrast  =  math.sqrt(contrast_sum / (M * N))
    
    return contrast

# %%
print(f'Contrast: {calculate_contrast(average_brightness , brightness_values , img_width , img_height )}')
# Out:
# Contrast: 8.032527484569064

# %% [markdown]
# ## Show the each of the RGB channels separately

# %%
def rgb_matrix(IMG , img_height , img_width  ) : 
    
    R_matrix = []
    G_matrix = []
    B_matrix = []
    
    for i in range(0 , img_height) :
        R_row = []
        G_row = []
        B_row = []
        for j in range(0 , img_width) :
            R_row.append(IMG[i][j][0])
            G_row.append(IMG[i][j][1])
            B_row.append(IMG[i][j][2])
        
        R_matrix.append(R_row)
        G_matrix.append(G_row)
        B_matrix.append(B_row)
    
    return R_matrix , G_matrix , B_matrix

# %%
R_matrix , G_matrix , B_matrix = rgb_matrix(IMG , img_height , img_width  )

# %%
R_matrix == G_matrix
# Out:
# False

# %% [markdown]
# ## Convert IMG to gray-level using the average method

# %%
def gray_level(IMG , img_height , img_width  ) :
    
    Gray_matrix = []
    for i in range(0 , img_height) :
        Gray_row = []
        for j in range(img_width):
            R = IMG[i][j][0]
            G = IMG[i][j][1]
            B = IMG[i][j][2]
            Gray = (R + G + B) // 3
            Gray_row.append(Gray)
        Gray_matrix.append(Gray_row)
    return Gray_matrix

# %%
Gray_matrix = gray_level(IMG , img_height , img_width  )

# %%
import numpy as np
import matplotlib.pyplot as plt

def show_grayscale(Gray_matrix):
    # Convert the matrix to a NumPy array
    Gray_array = np.array(Gray_matrix)
    
    # Display the grayscale image
    plt.imshow(Gray_array, cmap='gray')
    plt.title("Grayscale Image")
    plt.axis('off')  # Hide axes for a cleaner look
    plt.show()

# %% [markdown]
# ## Convert IMG to gray-level using the weighted formula

# %%
def gray_level_two(IMG , img_height , img_width  ) :
    
    Gray_matrix = []
    for i in range(0 , img_height) :
        Gray_row = []
        for j in range(img_width):
            R = IMG[i][j][0]
            G = IMG[i][j][1]
            B = IMG[i][j][2]
            Gray = (R * 0.29) +( G * 0.58) + (B * 0.11)
            Gray_row.append(Gray)
        Gray_matrix.append(Gray_row)
    return Gray_matrix

# %%
IMG_2 = gray_level_two(IMG , img_height , img_width  )

# %%
show_grayscale(IMG_2)

# %% [markdown]
# ## Determine the min / max value of IMG and IMG2

# %%
def min_max(img):
    min_val = IMG[0][0][0]
    max_val = IMG[0][0][0]
    
    for row in IMG:
        for pixel in row:
            for channel in pixel:  
                if channel < min_val:
                    min_val = channel
                if channel > max_val:
                    max_val = channel
    
    return min_val, max_val

# %%
print("IMG min / max:", min_max(IMG))
print("IMG2 min / max:", min_max(IMG_2))
# Out:
# IMG min / max: (0, 255)
# IMG2 min / max: (0, 255)

# %% [markdown]
# ## Calculate the pixel resolution of IMG and IMG2 in terms of MegaPixel

# %%
def mega_pixel(img_height, img_width):
    total_pixels = img_height * img_width
    megapixels = total_pixels / 1_000_000  
    return megapixels

# %%
print("IMG resolution in MP:", mega_pixel(len(IMG) , len(IMG[0])) )
print("IMG2 resolution in MP:", mega_pixel(len(IMG_2) , len(IMG_2[0])) )
# Out:
# IMG resolution in MP: 47.26611
# IMG2 resolution in MP: 47.26611

# %% [markdown]
# ## Calculate the size of IMG

# %%
def image_size(img_height, img_width, channels, bit_depth=8):
    size_in_bytes = img_height * img_width * channels * (bit_depth // 8)
    return size_in_bytes

# %%
print("IMG size in bytes:", image_size(len(IMG) , len(IMG[0]), 3))
# Out:
# IMG size in bytes: 141798330
