# %% [markdown]
# <div style="display: flex; background-color: RGB(190,22,220);" >
# <h1 style="margin: auto; padding: 30px; ">Wikipedia Data Scraping and Exploratory Data Analysis (EDA) Mini-Project  </h1>
# </div

# %% [markdown]
# <div style="border: 1px solid RGB(51,165,182);" >
# <h3 style="margin: auto; padding: 20px; color: RGB(51,165,182); ">  Initialization</h3>
#
# </div>

# %% [markdown]
# ```
# Brief introduction to Games and Toys as a concept.
# Importance of analyzing this category (e.g., its role in culture, development, or entertainment).
# Objectives of the project:
# Scrape data from Wikipedia.
# Structure the data into analyzable formats.
# Perform exploratory data analysis to derive insights.
# Tools and libraries used (e.g., Python, BeautifulSoup, pandas, matplotlib, etc.).
#
# ```

# %% [markdown]
# <div style="border: 1px solid RGB(51,165,182);" >
# <h3 style="margin: auto; padding: 20px; color: RGB(51,165,182); ">  Importing Libraries</h3>
# </div>

# %%
# Install required libraries

# !pip install wikipedia-api

# %%
import os
import requests
from bs4 import BeautifulSoup
import wikipediaapi
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
from sklearn.feature_extraction.text import TfidfVectorizer

# %% [markdown]
# <div style="border: 1px solid RGB(51,165,182);" >
# <h3 style="margin: auto; padding: 20px; color: RGB(51,165,182); ">  2. Dataset Scraping </h3>
# </div>

# %%
# Import Libraries


# # Initialize Wikipedia API with a valid User-Agent
# USER_AGENT = "salaheddine/1.0 (jawadkhenfer@gmail.com)"
# wiki_wiki = wikipediaapi.Wikipedia('en', headers={"User-Agent": USER_AGENT})

# # Helper Functions
# def calculate_text_complexity(text):
#     complex_words = len([word for word in text.split() if len(word) > 6])
#     avg_word_length = np.mean([len(word) for word in text.split()])
#     return round(complex_words * avg_word_length, 2)

# def calculate_readability(text):
#     words = text.split()
#     avg_sentence_length = len(words) / max(len(re.findall(r'\w+[.!?]', text)), 1)
#     syllable_count = sum(1 for word in words if len(word) > 2)
#     return round(206.835 - (1.015 * avg_sentence_length) - (84.6 * syllable_count / len(words)), 2)

# def extract_key_topics(text, top_n=5):
#     vectorizer = TfidfVectorizer(stop_words='english', max_features=top_n)
#     tfidf_matrix = vectorizer.fit_transform([text])
#     feature_names = vectorizer.get_feature_names_out()
#     return ', '.join(feature_names)

# def detect_age_group(text):
#     age_indicators = {
#         'children': ['kid', 'child', 'young', 'elementary'],
#         'teen': ['teen', 'teenage', 'adolescent'],
#         'adult': ['adult', 'professional', 'complex']
#     }
#     text_lower = text.lower()
#     for group, keywords in age_indicators.items():
#         if any(keyword in text_lower for keyword in keywords):
#             return group
#     return 'unspecified'
# def download_wikipedia_image(page_title):

#     # Construct Wikipedia page URL
#     url = f"https://en.wikipedia.org/wiki/{page_title.replace(' ', '_')}"

#     try:
#         # Fetch the page content
#         response = requests.get(url)
#         response.raise_for_status()  # Raise an exception for HTTP errors
#         soup = BeautifulSoup(response.content, 'html.parser')

#         # Find the first image element in the infobox or main content
#         img = soup.find('table', class_='infobox').find('img') if soup.find('table', class_='infobox') else soup.find('img')

#         if img:
#             # Get the image source
#             img_src = img.get('src')

#             # Ensure it's a full URL
#             if img_src and img_src.startswith('//'):
#                 img_src = 'https:' + img_src

#             # Return the image URL if valid
#             if img_src.startswith('https'):
#                 return img_src

#         return None  # No valid image found

#     except requests.exceptions.RequestException as e:
#         print(f"HTTP error: {e}")
#         return None
#     except Exception as e:
#         print(f"Error processing images for {page_title}: {e}")
#         return None

# def extract_advanced_features(page):
#     summary = page.summary

#     # Get image URLs using the full page URL
#     image_urls = download_wikipedia_image(page.title)

#     return {
#         'name': page.title,
#         'summary': summary,
#         'url': page.fullurl,
#         'image_urls': image_urls,
#         'text_length': len(summary),
#         'word_count': len(summary.split()),
#         'sentences_count': len(re.findall(r'\w+[.!?]', summary)),
#         'complexity_score': calculate_text_complexity(summary),
#         'readability_score': calculate_readability(summary),
#         'topic_keywords': extract_key_topics(summary),
#         'age_group_hint': detect_age_group(summary)
#     }
# def scrape_and_analyze(search_terms, max_depth=1):

#     scraped_data = []
#     visited_pages = set()

#     def scrape_page(page, depth):
#         if depth > max_depth or page.title in visited_pages or not page.exists():
#             return
#         visited_pages.add(page.title)
#         try:
#             features = extract_advanced_features(page)
#             scraped_data.append(features)
#             # Recursively scrape linked pages
#             for link_title in page.links.keys():
#                 link_page = wiki_wiki.page(link_title)
#                 scrape_page(link_page, depth + 1)
#         except Exception as e:
#             print(f"Error scraping page {page.title}: {e}")

#     for term in search_terms:
#         start_page = wiki_wiki.page(term)
#         scrape_page(start_page, 0)

#     return pd.DataFrame(scraped_data)


# # Save the dataset
# def save_dataset(df, filename='advanced_toys_dataset.csv'):
#     df.to_csv(filename, index=False)
#     print(f"Dataset saved: {filename}")

# # Main Execution
# search_terms = [
#     'Toys', 'Board Games', 'Video Games', 'Educational Toys', 'Classic Games',
#     'Children Toys', 'Puzzle Games', 'Vintage Toys', 'Action Figures',
#     'Outdoor Toys', 'Card Games', 'Creative Toys', 'Electronic Games',
#     'STEM Toys', 'Role-Playing Games', 'Family Games' ,
# ]

# toys_df = scrape_and_analyze(search_terms, max_depth=1)

# # Save the dataset
# save_dataset(toys_df)

# # Show the first few rows of the dataset
# toys_df

# %% [markdown]
# <div style="border: 1px solid RGB(51,165,182);" >
# <h3 style="margin: auto; padding: 20px; color: RGB(51,165,182); "> 3. Data Structuring </h3>
# </div>

# %% [markdown]
# ####  3 - 1 : load data and show it
# ---

# %%
toys_df = pd.read_csv('advanced_toys_dataset.csv' )  
toys_df
# Out:
#                                           name  \
# 0                                          Toy
# 1                  2007 Chinese export recalls
# 2                                  3D printing
# 3                                   Action Man
# 4                                Action figure
# ...                                        ...
# 2624                     White Wolf Publishing
# 2625                      Wizards of the Coast
# 2626  Wikipedia:WikiProject Role-playing games
# 2627                 Template talk:RPG sidebar
# 2628         Category:CS1 maint: date and year
#
#                                                 summary  \
# 0     A toy or plaything is an object that is used p...
# 1     In 2007, a series of product recalls and impor...
# 2     3D printing or additive manufacturing is the c...
# 3     Action Man is an action figure launched in Bri...
# 4     An action figure is a poseable character model...
# ...

# %% [markdown]
# #### 3- 2 :  info and Statistics
# ---

# %%
print("Dataset Info:")
print("-" * 40)
print(toys_df.info())

print("\nSummary Statistics:")
print("-" * 40)
print(toys_df.describe())
# Out:
# Dataset Info:
# ----------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2629 entries, 0 to 2628
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               2629 non-null   object
#  1   summary            2629 non-null   object
#  2   url                2629 non-null   object
#  3   image_urls         1221 non-null   object
#  4   text_length        2629 non-null   int64
#  5   word_count         2629 non-null   int64
#  6   sentences_count    2629 non-null   int64
#  7   complexity_score   2629 non-null   float64
#  8   readability_score  2629 non-null   float64
#  9   topic_keywords     2629 non-null   object
#  10  age_group_hint     2629 non-null   object
# dtypes: float64(2), int64(3), object(6)
# memory usage: 226.1+ KB
# None
#
# Summary Statistics:
# ----------------------------------------
# ...

# %% [markdown]
# #### 3 - 3   missing Values

# %%
print(toys_df.isnull().sum())
# Out:
# name                    0
# summary                 0
# url                     0
# image_urls           1408
# text_length             0
# word_count              0
# sentences_count         0
# complexity_score        0
# readability_score       0
# topic_keywords          0
# age_group_hint          0
# dtype: int64

# %% [markdown]
# #### 3 - 4 : removing massing  values
# ---

# %%
# Drop rows where 'image_urls' is null
df_non_null = toys_df.dropna(subset=["image_urls"])

# Reset the index and drop the old index
toys_df = df_non_null.reset_index(drop=True)
toys_df
# Display the resulting DataFrdf_non_null
# Out:
#                                        name  \
# 0                                Action Man
# 1                             Action figure
# 2                             Action figure
# 3     North American International Toy Fair
# 4                             Ancient Egypt
# ...                                     ...
# 1216                                Therapy
# 1217                            VentureBeat
# 1218               Werewolf: The Apocalypse
# 1219                  White Wolf Publishing
# 1220                   Wizards of the Coast
#
#                                                 summary  \
# 0     Action Man is an action figure launched in Bri...
# 1     An action figure is a poseable character model...
# 2     An action figure is a poseable character model...
# 3     The North American International Toy Fair (for...
# 4     Ancient Egypt was a civilization of ancient No...
# ...                                                 ...
# ...

# %%
df = toys_df 

plt.subplot()
df['age_group_hint'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Age Group Distribution')
plt.show()

# %%
import pandas as pd


# Simulate loading your data
data =toys_df # Replace with your actual CSV path

# Ensure rows with NaN age_group_hint are dropped (clean data)
data.dropna(subset=["age_group_hint"], inplace=True)

# Define a heuristic rule function
def predict_age_group(topic_keywords):
    """
    Predict the age group based on heuristic rules.
    :param topic_keywords: Text related to the topic.
    :return: Predicted age group ('children', 'teen', 'adult')
    """
    # Convert text to lowercase for consistent keyword matching
    topic_keywords = topic_keywords.lower()
    
    # Rule-based heuristic logic
    if any(keyword in topic_keywords for keyword in ["toy", "playing", "child", "children"]):
        return "children"
    elif any(keyword in topic_keywords for keyword in ["game", "video game", "teen", "youth"]):
        return "teen"
    else:
        return "adult"


# Apply heuristic logic only to rows labeled 'unspecified'
data["predicted_age_group"] = data["topic_keywords"].apply(
    lambda x: predict_age_group(x) if x else "adult"
)

# Output the predictions for rows labeled "unspecified"
unspecified_rows = data[data["age_group_hint"] == "unspecified"]

# Print only these rows
print(unspecified_rows[["name", "topic_keywords", "predicted_age_group"]])

toys_df['age_group_hint'] = unspecified_rows['age_group_hint']
# Out:
#                           name  \
# 0                   Action Man
# 4                Ancient Egypt
# 9               Brio (company)
# 10                       Banpo
# 11                      Barbie
# ...                        ...
# 1215       Steve Jackson Games
# 1217               VentureBeat
# 1218  Werewolf: The Apocalypse
# 1219     White Wolf Publishing
# 1220      Wizards of the Coast
#
#                                        topic_keywords predicted_age_group
# 0                      1966, action, figure, joe, man               adult
# 4     ancient, civilization, egypt, egyptian, kingdom               adult
# 9                    brio, company, ivar, scania, toy            children
# 10                      12, banpo, bce, located, site               adult
# 11         accessories, barbie, doll, fashion, mattel               adult
# ...                                               ...                 ...
# ...

# %%
plt.subplot()
toys_df['predicted_age_group'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Age Group Distribution')
plt.show()

# %% [markdown]
# <div style="border: 1px solid RGB(51,165,182);" >
# <h3 style="margin: auto; padding: 20px; color: RGB(51,165,182); ">  4. Exploratory Data Analysis </h3>
# </div>

# %% [markdown]
# #### 4-1 : Descriptive Statistics:
# ----

# %%
print("Dataset Info:")
print("-" * 40)
print(toys_df.info())

print("\nSummary Statistics:")
print("-" * 40)
print(toys_df.describe())
# Out:
# Dataset Info:
# ----------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1221 entries, 0 to 1220
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   name                 1221 non-null   object
#  1   summary              1221 non-null   object
#  2   url                  1221 non-null   object
#  3   image_urls           1221 non-null   object
#  4   text_length          1221 non-null   int64
#  5   word_count           1221 non-null   int64
#  6   sentences_count      1221 non-null   int64
#  7   complexity_score     1221 non-null   float64
#  8   readability_score    1221 non-null   float64
#  9   topic_keywords       1221 non-null   object
#  10  age_group_hint       985 non-null    object
#  11  predicted_age_group  1221 non-null   object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 114.6+ KB
# None
#
# Summary Statistics:
# ...

# %%
print(toys_df.isnull().sum())
# Out:
# name                     0
# summary                  0
# url                      0
# image_urls               0
# text_length              0
# word_count               0
# sentences_count          0
# complexity_score         0
# readability_score        0
# topic_keywords           0
# age_group_hint         236
# predicted_age_group      0
# dtype: int64

# %%
print(toys_df.info())
print(toys_df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1221 entries, 0 to 1220
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   name                 1221 non-null   object
#  1   summary              1221 non-null   object
#  2   url                  1221 non-null   object
#  3   image_urls           1221 non-null   object
#  4   text_length          1221 non-null   int64
#  5   word_count           1221 non-null   int64
#  6   sentences_count      1221 non-null   int64
#  7   complexity_score     1221 non-null   float64
#  8   readability_score    1221 non-null   float64
#  9   topic_keywords       1221 non-null   object
#  10  age_group_hint       985 non-null    object
#  11  predicted_age_group  1221 non-null   object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 114.6+ KB
# None
#        text_length   word_count  sentences_count  complexity_score  \
# ...

# %% [markdown]
# #### 4-2 : Visualizations:
# -----

# %% [markdown]
# ##### 4 -2-1. Age Group Distribution

# %%
# 3. Age Group Distribution

toys_df['predicted_age_group'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Age Group Distribution')
plt.show()

# %% [markdown]
# ```
# children :
# here  we  found  that  we have  the  %  of children is 3.9% the less  one of them
# which mean those games  that  we have  not all of them for children
#
# adult  and tenn :
#  we  see here the  % for those  two  is allmost  rthe same so  i  think  this data for  adult and  tenn more
#
# result :
# i think  becouse this data came from net  so  it has  related with  video  games and  this last one for the  adult and teen
#
#
#
# ```

# %%
# 1. Complexity Score Distribution

sns.histplot(df['complexity_score'], kde=True)
plt.title('Text Complexity Distribution')
plt.show()

# %% [markdown]
# ```
# we can notice here  the  most  complexty  of this test  is 100 so
# we  found here  the most  of data is  around  bettween the 100 and 150
# ```

# %%
# 4. Correlation Heatmap

numeric_df = toys_df.select_dtypes(include=['number'])  # Select only numeric columns
correlation_matrix = numeric_df.corr()  # Calculate the correlation matrix

# Plot the heatmap
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f",
            vmin=-1,  # Set minimum value of the heatmap scale
            vmax=1) 
plt.title('Feature Correlations')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Select only numeric features for correlation and visualization
features = ['text_length', 'sentences_count', 'complexity_score', 'readability_score']

# Plot the distributions of these features grouped by 'predicted_age_group'
plt.figure(figsize=(15, 10))
for i, feature in enumerate(features, 1):
    plt.subplot(2, 2, i)  # Adjust rows and columns based on the number of features
    sns.histplot(data=toys_df, x=feature, hue='predicted_age_group', bins=30, multiple="stack")
    plt.title(f'Distribution of {feature}')
plt.tight_layout()
plt.show()

# Correlation heatmap for the selected numerical features
correlation_matrix = toys_df[features].corr()  # Correlation matrix using only numerical features
plt.figure(figsize=(10, 10))
sns.heatmap(
    correlation_matrix, 
    annot=True, 
    cmap='coolwarm', 
    center=0, 
    vmin=-1, 
    vmax=1
)
plt.title('Correlation Heatmap for Selected Features')
plt.show()

# %% [markdown]
# <div style="border: 1px solid RGB(51,165,182);" >
#  <h3 style="margin: auto; padding: 20px; color: RGB(51,165,182); ">   Save  the  data like csv </h3>
# </div >

# %%
toys_df.to_csv('output.csv', index=False)  # Save to a new CSV

# %% [markdown]
# <div style="border: 1px solid RGB(51,165,182);" >
#  <h3 style="margin: auto; padding: 20px; color: RGB(51,165,182); ">   The test  of web  </h3>
# </div >

# %% [markdown]
# ### after  all  we have this data  is clean and  we can use  it in our app you  can  finr
# -----

# %%
from IPython.display import HTML, display

# Display a clickable link that will open the HTML file in a new tab
display(HTML('<a href="wikipedia-search-app.html" target="_blank">Open Wikipedia Search App in New Tab</a>'))
# Out:
# <a href="wikipedia-search-app.html" target="_blank">Open Wikipedia Search App in New Tab</a>
